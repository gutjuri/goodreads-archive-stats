# %%
import pandas as pd
import seaborn as sns

bookdata = pd.read_csv("~/Documents/Anderes/books.csv",
                       parse_dates=["Date Read", "Date Added"])
by_mon = bookdata.groupby([bookdata["Date Read"].dt.year, bookdata["Date Read"].dt.month]).count()[
    "Title"].plot(kind="bar")
